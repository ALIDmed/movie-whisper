# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We are interested in 2017 films

# %%
movies_metadata = pd.read_csv('../data/movies_metadata.csv')
movies_metadata.head()
# Out:
# C:\Users\ali\AppData\Local\Temp\ipykernel_2456\2436961127.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_metadata = pd.read_csv('../data/movies_metadata.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
movies_metadata.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
movies_metadata = movies_metadata[['title', 'release_date', 'id', 'genres']]
movies_metadata.head()
# Out:
#                          title release_date     id  \
# 0                    Toy Story   1995-10-30    862
# 1                      Jumanji   1995-12-15   8844
# 2             Grumpier Old Men   1995-12-22  15602
# 3            Waiting to Exhale   1995-12-22  31357
# 4  Father of the Bride Part II   1995-02-10  11862
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]

# %%
movies_metadata.release_date = pd.to_datetime(movies_metadata.release_date, errors='coerce')

# %%
movies_metadata['year'] = movies_metadata.release_date.dt.year

# %%
movies_metadata['year'].min(), movies_metadata['year'].max()
# Out:
# (1874.0, 2020.0)

# %%
movies_metadata = movies_metadata.loc[movies_metadata['year']==2017, ['title', 'id', 'genres', 'year']]

# %%
movies_metadata['id'] = movies_metadata['id'].astype(int)

# %%
movies_metadata.head()
# Out:
#                                                   title      id  \
# 26560  Pirates of the Caribbean: Dead Men Tell No Tales  166426
# 26561                                    Justice League  141052
# 26565                                    Thor: Ragnarok  284053
# 26566                    Guardians of the Galaxy Vol. 2  283995
# 30536                               The King's Daughter  245842
#
#                                                   genres    year
# 26560  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  2017.0
# 26561  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  2017.0
# 26565  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  2017.0
# 26566  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  2017.0
# 30536  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...  2017.0

# %%
credits = pd.read_csv('../data/credits.csv')

# %%
credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
df = pd.merge(movies_metadata, credits, on='id')

# %%
df
# Out:
#                                                 title      id  \
# 0    Pirates of the Caribbean: Dead Men Tell No Tales  166426
# 1                                      Justice League  141052
# 2                                      Thor: Ragnarok  284053
# 3                      Guardians of the Galaxy Vol. 2  283995
# 4                                 The King's Daughter  245842
# ..                                                ...     ...
# 526                  Thick Lashes of Lauri Mäntyvaara  468707
# 527                       Cop and a Half: New Recruit  461297
# 528                                    In a Heartbeat  455661
# 529                                               Mom  404604
# 530                                          Queerama  461257
#
#                                                 genres    year  \
# 0    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  2017.0
# 1    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  2017.0
# ...

# %%
df.loc[0, 'genres']
# Out:
# "[{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': 14, 'name': 'Fantasy'}, {'id': 35, 'name': 'Comedy'}]"

# %%
import ast

df['genres'] = df['genres'].apply(ast.literal_eval)
df['cast'] = df['cast'].apply(ast.literal_eval)
df['crew'] = df['crew'].apply(ast.literal_eval)

# %%
def extract_genres(x):
    genres = []
    for i in x:
        genres.append(i['name'])

    if genres == []:
        return np.NaN
    
    return " ".join(genres)

# %%
df['genres'] = df['genres'].apply(extract_genres)
df['genres'] = df['genres'].str.replace('Science Fiction', 'Sci-Fi')

# %%
def get_actor_by_num(x, num):
    if len(x) < num:
        return np.NaN
    return x[num-1].get('name', np.NaN)

# %%
df['actor_1_name'] = df['cast'].apply(lambda x: get_actor_by_num(x, 1))
df['actor_2_name'] = df['cast'].apply(lambda x: get_actor_by_num(x, 2))
df['actor_3_name'] = df['cast'].apply(lambda x: get_actor_by_num(x, 3))

# %%
def get_director_name(x):
    directors = []
    for i in x:
        if i['job'] == 'Director':
            directors.append(i['name'])

    if directors == []:
        return np.NaN

    return " ".join(directors)

# %%
df['director_name'] = df['crew'].apply(get_director_name)

# %%
df = df[['title', 'genres', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'director_name']]

# %%
df.rename(columns={'title':'movie_title'}, inplace=True)
df.movie_title = df.movie_title.str.lower()
# Out:
# C:\Users\ali\AppData\Local\Temp\ipykernel_2456\998558313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'title':'movie_title'}, inplace=True)
# C:\Users\ali\AppData\Local\Temp\ipykernel_2456\998558313.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.movie_title = df.movie_title.str.lower()

# %%
old = pd.read_csv('../data/data.csv')

# %%
new = pd.concat([old, df], ignore_index=True)

# %%
new
# Out:
#                                             movie_title  \
# 0                                                Avatar
# 1              Pirates of the Caribbean: At World's End
# 2                                               Spectre
# 3                                 The Dark Knight Rises
# 4     Star Wars: Episode VII - The Force Awakens    ...
# ...                                                 ...
# 5569                   thick lashes of lauri mäntyvaara
# 5570                        cop and a half: new recruit
# 5571                                     in a heartbeat
# 5572                                                mom
# 5573                                           queerama
#
#                  director_name          actor_1_name      actor_2_name  \
# 0                James Cameron           CCH Pounder  Joel David Moore
# 1               Gore Verbinski           Johnny Depp     Orlando Bloom
# 2                   Sam Mendes       Christoph Waltz      Rory Kinnear
# ...

# %%
new.to_csv('../data/new_data.csv', index=False)
